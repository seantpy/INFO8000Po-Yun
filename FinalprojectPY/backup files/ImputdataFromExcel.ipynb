# %%
import sqlite3 as sql
import pandas as pd
#from sklearn.linear_model import LinearRegression
#from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
from scipy import optimize
import pandas as pd
import numpy as np
import seaborn as sns
from urllib.request import urlretrieve
import pandas as pd
from sklearn.linear_model import LinearRegression
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import sqlite3 as sql

sns.set()

# %%
conn = sql.connect("GHdata.db")
cursor = conn.execute("select * from Greenhousedata")
df1 = pd.DataFrame(cursor.fetchall(),columns = ['GenotypeNumber','Genotype','rep','exp','DAI3','DAI5','DAI7','DAI9']) 
df2 = pd.read_excel("INFO8000Final_RawData_2Exp.xlsx")
df3 =df2.round(decimals = 3)
cursor = conn.execute("select * from Greenhousedata") 
df3.to_sql("Greenhousedata", conn, if_exists='append', index = False)
df = pd.DataFrame(cursor.fetchall(),columns = ['GenotypeNumber','Genotype','rep','exp','DAI3','DAI5','DAI7','DAI9']) 
df
print(df)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-33-c352d8aad6ee> in <module>
#       5 df3 =df2.round(decimals = 3)
#       6 cursor = conn.execute("select * from Greenhousedata")
# ----> 7 df3.to_sql("Greenhousedata", conn, if_exists='append', index = False)
#       8 df = pd.DataFrame(cursor.fetchall(),columns = ['GenotypeNumber','Genotype','rep','exp','DAI3','DAI5','DAI7','DAI9'])
#       9 df
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2661             chunksize=chunksize,
#    2662             dtype=dtype,
# -> 2663             method=method,
#    2664         )
#    2665
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/io/sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     519         chunksize=chunksize,
#     520         dtype=dtype,
# --> 521         method=method,
#     522     )
#     523
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/io/sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1732         )
#    1733         table.create()
# -> 1734         table.insert(chunksize, method)
#    1735
#    1736     def has_table(self, name, schema=None):
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/io/sql.py in insert(self, chunksize, method)
#     753
#     754                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 755                 exec_insert(conn, keys, chunk_iter)
#     756
#     757     def _query_iterator(
#
# /opt/anaconda3/lib/python3.7/contextlib.py in __exit__(self, type, value, traceback)
#     117         if type is None:
#     118             try:
# --> 119                 next(self.gen)
#     120             except StopIteration:
#     121                 return False
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/io/sql.py in run_transaction(self)
#    1571         try:
#    1572             yield cur
# -> 1573             self.con.commit()
#    1574         except Exception:
#    1575             self.con.rollback()
#
# OperationalError: database is locked

# %%
df2
# Out:
#      GenotypeNumber genotype  Rep  Exp     DAI3     DAI5     DAI7     DAI9
# 0                15      13M    1    1  0.22050  0.23400  0.41750  0.60900
# 1                15      13M    2    1  0.13300  0.19800  0.37500  0.62000
# 2                15      13M    3    1  0.18650  0.18650  0.18650  0.35250
# 3                15      13M    4    1  0.13000      NaN      NaN      NaN
# 4                15      13M    5    1  0.20800  0.24250  0.24900  0.44650
# ..              ...      ...  ...  ...      ...      ...      ...      ...
# 154              15      13M    2    2  0.13462  0.10287  0.27940  0.27940
# 155              15      13M    3    2  0.21082  0.23876  0.23876  0.26035
# 156              15      13M    4    2  0.23114  0.23876  0.48133  0.52832
# 157              15      13M    5    2  0.11557  0.30480  0.40132  0.40100
# 158              15      13M    6    2  0.12800  0.12800  0.15621  0.15621
#
# [159 rows x 8 columns]

# %%
df3 =df2.round(decimals = 3)
df3
# Out:
#      GenotypeNumber genotype  Rep  Exp   DAI3   DAI5   DAI7   DAI9
# 0                15      13M    1    1  0.220  0.234  0.418  0.609
# 1                15      13M    2    1  0.133  0.198  0.375  0.620
# 2                15      13M    3    1  0.186  0.186  0.186  0.352
# 3                15      13M    4    1  0.130    NaN    NaN    NaN
# 4                15      13M    5    1  0.208  0.242  0.249  0.446
# ..              ...      ...  ...  ...    ...    ...    ...    ...
# 154              15      13M    2    2  0.135  0.103  0.279  0.279
# 155              15      13M    3    2  0.211  0.239  0.239  0.260
# 156              15      13M    4    2  0.231  0.239  0.481  0.528
# 157              15      13M    5    2  0.116  0.305  0.401  0.401
# 158              15      13M    6    2  0.128  0.128  0.156  0.156
#
# [159 rows x 8 columns]

# %%
df3.to_sql("Greenhousedata", conn, if_exists='replace', index = False)
df = pd.DataFrame(cursor.fetchall(),columns = ['GenotypeNumber','Genotype','rep','exp','DAI3','DAI5','DAI7','DAI9']) 
df
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /opt/anaconda3/lib/python3.7/site-packages/pandas/io/sql.py in execute(self, *args, **kwargs)
#    1585         try:
# -> 1586             cur.execute(*args, **kwargs)
#    1587             return cur
#
# OperationalError: database table is locked
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# <ipython-input-26-665055d50333> in <module>
# ----> 1 df3.to_sql("Greenhousedata", conn, if_exists='replace', index = False)
#       2 df = pd.DataFrame(cursor.fetchall(),columns = ['GenotypeNumber','Genotype','rep','exp','DAI3','DAI5','DAI7','DAI9'])
#       3 df
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2661             chunksize=chunksize,
#    2662             dtype=dtype,
# -> 2663             method=method,
#    2664         )
#    2665
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/io/sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#     519         chunksize=chunksize,
#     520         dtype=dtype,
# --> 521         method=method,
#     522     )
#     523
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/io/sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method)
#    1731             dtype=dtype,
#    1732         )
# -> 1733         table.create()
#    1734         table.insert(chunksize, method)
#    1735
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/io/sql.py in create(self)
#     646                 raise ValueError(f"Table '{self.name}' already exists.")
#     647             elif self.if_exists == "replace":
# --> 648                 self.pd_sql.drop_table(self.name, self.schema)
#     649                 self._execute_create()
#     650             elif self.if_exists == "append":
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/io/sql.py in drop_table(self, name, schema)
#    1749     def drop_table(self, name, schema=None):
#    1750         drop_sql = f"DROP TABLE {_get_valid_sqlite_name(name)}"
# -> 1751         self.execute(drop_sql)
#    1752
#    1753     def _create_sql_schema(self, frame, table_name, keys=None, dtype=None):
#
# /opt/anaconda3/lib/python3.7/site-packages/pandas/io/sql.py in execute(self, *args, **kwargs)
#    1596
#    1597             ex = DatabaseError(f"Execution failed on sql '{args[0]}': {exc}")
# -> 1598             raise ex from exc
#    1599
#    1600     @staticmethod
#
# DatabaseError: Execution failed on sql 'DROP TABLE "Greenhousedata"': database table is locked

# %%
conn = sql.connect("GHdata.db")
conn.execute ("""
drop table if exists Greenhousedata
""")
conn.execute ("""
CREATE TABLE Greenhousedata (GenotypeNumber,Genotype,rep,exp,DAI3,DAI5,DAI7,DAI9);
""")
cursor = conn.execute("select * from Greenhousedata")
df2 = pd.read_excel("INFO8000Final_RawData_2Exp.xlsx")
df3 = df2.round(decimals = 3)
df2.to_sql("Greenhousedata", conn, if_exists='append', index=False)
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# <ipython-input-27-183ae063e72b> in <module>
#       2 conn.execute ("""
#       3 drop table if exists Greenhousedata
# ----> 4 """)
#       5 conn.execute ("""
#       6 CREATE TABLE Greenhousedata (GenotypeNumber,Genotype,rep,exp,DAI3,DAI5,DAI7,DAI9);
#
# OperationalError: database is locked

# %%
con = sql.connect("GHdata.db") 

cur = con.cursor()  
cur.execute("select * from Greenhousedata")
df = pd.DataFrame(cur.fetchall(),columns = ['GenotypeNumber','Genotype','rep','exp','DAI3','DAI5','DAI7','DAI9']) 


df2 = pd.read_excel("INFO8000Final_RawData_2Exp.xlsx")
df3 = df2.round(decimals = 3)
df2.to_sql("Greenhousedata", conn, if_exists='append', index=False)
df5 = pd.DataFrame(cur.fetchall(),columns = ['GenotypeNumber','Genotype','rep','exp','DAI3','DAI5','DAI7','DAI9'])

# %%
df5
# Out:
# Empty DataFrame
# Columns: [GenotypeNumber, Genotype, rep, exp, DAI3, DAI5, DAI7, DAI9]
# Index: []

# %%
df
