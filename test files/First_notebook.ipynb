# %%
import requests #great web library
import pandas as pd #great table/dataframe library
doc_id = "1mJcXk8iq5izGwCXbnTXc4X81LbPgYv4GPxjT4a53Y00"
url = f"https://docs.google.com/spreadsheets/d/{doc_id}/gviz/tq?tqx=out:csv" #beautiful python syntactic sugar
res = requests.get(url,allow_redirects=True) #Does the download
open('./temp.csv', 'wb').write(res.content) #temporarily write to a file
df = pd.read_csv('./temp.csv') #so that we can read it. 
df.head() #so we can see that it worked
# Out:
#            Timestamp First Name (Given)      Last Name      PhD or MS  \
# 0  1/7/2020 16:28:29          Yun-Ching           Tsai            PhD
# 1  1/7/2020 16:29:15              Anton  Franzluebbers            PhD
# 2  1/7/2020 16:29:21              Holly          Munro            PhD
# 3  1/7/2020 16:29:21               Kyle        Johnsen  Completed PhD
# 4  1/7/2020 16:29:24              Corey        Schultz            PhD
#
#   Graduate Program of Study (e.g. Electrical and Computer Engineering)  \
# 0                                    Plant Pathology
# 1                Electrical and Computer Engineering
# 2                   Forest Entomology and Biometrics
# 3                               Computer Engineering
# 4                                     Bioinformatics
#
#               Undergraduate Program of Study  \
# 0                                        NaN
# 1  Computer Science and Computer Engineering
# 2                                    Biology
# 3                       Computer Engineering
# 4                                   Genetics
#
#    Level of Experience With Statistics  \
# 0                                    5
# 1                                    2
# 2                                    5
# 3                                    3
# 4                                    3
#
#    Level of Experience With Machine Learning  \
# 0                                          1
# 1                                          2
# 2                                          4
# 3                                          4
# 4                                          1
#
#    Level of Experience With Programming  Level of Experience With Python  \
# 0                                     2                                1
# 1                                     5                                4
# 2                                     4                                2
# 3                                     5                                4
# 4                                     4                                3
#
#    Level of Experience With R  Level of Experience With SQL/Databases  \
# 0                           3                                       1
# 1                           3                                       2
# 2                           4                                       2
# 3                           4                                       5
# 4                           3                                       1
#
#    Level of Experience With Web APIs  \
# 0                                  1
# 1                                  2
# 2                                  2
# 3                                  5
# 4                                  1
#
#                              Upload a picture of you  \
# 0                                                NaN
# 1  https://drive.google.com/open?id=10m07Hpq8ldGu...
# 2  https://drive.google.com/open?id=1HFV4H4TjaKUS...
# 3  https://drive.google.com/open?id=1c_Bmz2PkB_cq...
# 4  https://drive.google.com/open?id=10hjo5M6n8HR0...
#
#                       Interesting fact(s) about you.  \
# 0                                                NaN
# 1                                     I like carrots
# 2                             I have pet tarantulas
# 3  I have two daughters, 6 & 8, and a dog (and a ...
# 4  I enjoy visiting National Parks. I have a twin...
#
#   Where were you born? (city, state, country)  \
# 0                              Tainan, Taiwan
# 1                             Athens, GA, USA
# 2                             Athens, GA, USA
# 3               Port Jefferson, New York, USA
# 4                            Bristol, CT, USA
#
#    Number of members of your immediate family (parents, brothers, sisters)
# 0                                                  4
# 1                                                  5
# 2                                                  5
# 3                                                  5
# 4                                                  4
