# %%
#4-1
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import seaborn as sns
import numpy as np
import pandas as pd

# %%
titanic_df = sns.load_dataset("titanic")
display(titanic_df)
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
#4-2-0 IMPORT DATA
dataset =titanic_df

a1=pd.DataFrame()
a1["Number"]=dataset.isnull().sum()
df1 = pd.DataFrame({"name":["survived","pclass","sex","age","sibsp","parch","fare","embarked","class","who","adult_male","deck","embark_town","alive","alone"],"number":[0,0,0,177,0,0,0,2,0,0,0,688,2,0,0]})
a2=pd.DataFrame()
a2["Number"]=dataset.isnull().sum(axis=1)

# %%
#4-2-a 
fig=plt.figure(figsize=(30,10))
ax1 = fig.add_subplot()
sns.catplot(x="number", y="name", data=df1, kind="bar",ax=ax1)

# %%
#4-2-b 
fig2=plt.figure(figsize=(10,10))
ax2 = fig2.add_subplot()
sns.catplot(x="Number", data=a2, kind="count",ax=ax2)

# %%
#4-2-c 
fig3=plt.figure(figsize=(10,10))
ax3 = fig3.add_subplot()
sns.catplot(x="number", y="name", data=df1, kind="bar",ax=ax3)
sns.catplot(x="Number", data=a2, kind="count",ax=ax3)

# %%
#4-3-a
titanic_df2 = sns.load_dataset("titanic")
df3= titanic_df2.dropna(subset=["age"])
sns.relplot(data=df3,x="age",y="fare",hue = "survived", kind="scatter",col="survived")

# %%
#4-3-b
df3=titanic_df.dropna(subset=["age"])
df4=df3.iloc[:,3]
test1=pd.DataFrame()
test1["age"]= df4
test1['age_bins'] = pd.cut(x= test1['age'], bins=[0,18, 45, 65, 100])
test1['age_bins'].unique()
test1['group'] = pd.cut(x=test1['age'], bins=[0,18, 45, 65, 100], labels=['child', 'young adult','adult','old adult'])
test1["survival"]= df3["survived"]
display(test1)

#show both survived or not survived
sns.catplot(data=test1,x="group",hue = "survival", kind="count")

#show only survived
indexNames = test1[ test1['survival'] == 0 ].index
test1.drop(indexNames , inplace=True)
test1
fig4=plt.figure(figsize=(20,10))
ax = fig4.add_subplot()
sns.catplot(x="group", data=test1, kind="count",ax=ax)
# Out:
#       age  age_bins        group  survival
# 0    22.0  (18, 45]  young adult         0
# 1    38.0  (18, 45]  young adult         1
# 2    26.0  (18, 45]  young adult         1
# 3    35.0  (18, 45]  young adult         1
# 4    35.0  (18, 45]  young adult         0
# ..    ...       ...          ...       ...
# 885  39.0  (18, 45]  young adult         0
# 886  27.0  (18, 45]  young adult         0
# 887  19.0  (18, 45]  young adult         1
# 889  26.0  (18, 45]  young adult         1
# 890  32.0  (18, 45]  young adult         0
#
# [714 rows x 4 columns]

# %%
#4-3-c1
sns.catplot(data=df3,x="sex",y="age",hue = "survived", kind="strip")

# %%
#4-3-c2
sns.catplot(data=df3,x="who",hue = "survived", kind="count")

# %%
#4-3-c3
sns.catplot(data=df3,x="class",hue = "survived", kind="count")
