# %%
reg = linear_model.LinearRegression()
y1 = test1_index['Red quality'].values.reshape(-1,1)
x1 = test1_index['index'].values.reshape(-1,1)
f = plt.figure(figsize=(10,10))
ax = f.add_subplot (111)
ax.plot(x1,y1,"o")


def loss_function(w,x1,y1):
    y_pred = w[0]*x1 + w[1]
    error = np.sum((y_pred-y1)**2)
    return error

w1=optimize.minimize(loss_function,[0,0],args=(x1,y1))
w1.x





reg = linear_model.LinearRegression()
y2 = test1_index['White quality'].values.reshape(-1,1)
x2 = test1_index['index'].values.reshape(-1,1)
f = plt.figure(figsize=(10,10))
ax = f.add_subplot (111)
ax.plot(x2,y2,"o")


def loss_function(w,x2,y2):
    y_pred = w[0]*x2 + w[1]
    error = np.sum((y_pred-y2)**2)
    return error

w2=optimize.minimize(loss_function,[0,0],args=(x2,y2))
w2.x




df_row = pd.concat([data_white, data_red])
test2=pd.DataFrame()

test2["combine_quality"]=df_row["quality (0-10)"]
test2_index = test2.reset_index()
display(test2_index)


reg = linear_model.LinearRegression()
y3 = test1_index['White quality'].values.reshape(-1,1)
x3 = test1_index['index'].values.reshape(-1,1)
f = plt.figure(figsize=(10,10))
ax = f.add_subplot (111)
ax.plot(x3,y3,"o")


def loss_function(w,x3,y3):
    y_pred = w[0]*x3 + w[1]
    error = np.sum((y_pred-y3)**2)
    return error

w3=optimize.minimize(loss_function,[0,0],args=(x3,y3))
w3.x
